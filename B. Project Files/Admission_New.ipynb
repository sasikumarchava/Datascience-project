# %%
#importing necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Loading dataset
data = pd.read_csv('Admission Data.csv')

# %% [markdown]
# # Data Preprocessing

# %%
#Data inspection
data.head()
# Out:
#    Serial_No  GRE_Score  TOEFL_Score  University_Rating  SOP  LOR  CGPA  \
# 0          1        337          118                  4  4.5  4.5  9.65
# 1          2        324          107                  4  4.0  4.5  8.87
# 2          3        316          104                  3  3.0  3.5  8.00
# 3          4        322          110                  3  3.5  2.5  8.67
# 4          5        314          103                  2  2.0  3.0  8.21
#
#    Research  Chance_of_Admit
# 0         1             0.92
# 1         1             0.76
# 2         1             0.72
# 3         1             0.80
# 4         0             0.65

# %%
# checking the dataype of the parameters(Columns)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Serial_No          400 non-null    int64
#  1   GRE_Score          400 non-null    int64
#  2   TOEFL_Score        400 non-null    int64
#  3   University_Rating  400 non-null    int64
#  4   SOP                400 non-null    float64
#  5   LOR                400 non-null    float64
#  6   CGPA               400 non-null    float64
#  7   Research           400 non-null    int64
#  8   Chance_of_Admit    400 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 28.2 KB

# %%
# Descriptive Analysis
data.describe()
# Out:
#         Serial_No   GRE_Score  TOEFL_Score  University_Rating         SOP  \
# count  400.000000  400.000000   400.000000         400.000000  400.000000
# mean   200.500000  316.807500   107.410000           3.087500    3.400000
# std    115.614301   11.473646     6.069514           1.143728    1.006869
# min      1.000000  290.000000    92.000000           1.000000    1.000000
# 25%    100.750000  308.000000   103.000000           2.000000    2.500000
# 50%    200.500000  317.000000   107.000000           3.000000    3.500000
# 75%    300.250000  325.000000   112.000000           4.000000    4.000000
# max    400.000000  340.000000   120.000000           5.000000    5.000000
#
#               LOR        CGPA    Research  Chance_of_Admit
# count  400.000000  400.000000  400.000000       400.000000
# mean     3.452500    8.598925    0.547500         0.724350
# std      0.898478    0.596317    0.498362         0.142609
# min      1.000000    6.800000    0.000000         0.340000
# 25%      3.000000    8.170000    0.000000         0.640000
# 50%      3.500000    8.610000    1.000000         0.730000
# 75%      4.000000    9.062500    1.000000         0.830000
# max      5.000000    9.920000    1.000000         0.970000

# %%
data.mean()
# Out:
# Serial_No            200.500000
# GRE_Score            316.807500
# TOEFL_Score          107.410000
# University_Rating      3.087500
# SOP                    3.400000
# LOR                    3.452500
# CGPA                   8.598925
# Research               0.547500
# Chance_of_Admit        0.724350
# dtype: float64

# %%
# Checking the null values in dataset
data.isnull().any()
# Out:
# Serial_No            False
# GRE_Score            False
# TOEFL_Score          False
# University_Rating    False
# SOP                  False
# LOR                  False
# CGPA                 False
# Research             False
# Chance_of_Admit      False
# dtype: bool

# %%
data.isnull().sum()
# Out:
# Serial_No            0
# GRE_Score            0
# TOEFL_Score          0
# University_Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance_of_Admit      0
# dtype: int64

# %% [markdown]
# # Data Visualization

# %%
#BarPlot
plt.bar(data['TOEFL_Score'],data['Chance_of_Admit'])
# Out:
# <BarContainer object of 400 artists>

# %%
#BarPlot
plt.bar(data['GRE_Score'],data['Chance_of_Admit'])
# Out:
# <BarContainer object of 400 artists>

# %%
#BarPlot
plt.bar(data['University_Rating'],data['Chance_of_Admit'])
# Out:
# <BarContainer object of 400 artists>

# %%
#Pie Chart
plt.pie(data['Chance_of_Admit'],autopct='%.2f')
# Out:
# ([<matplotlib.patches.Wedge at 0x20a4cd157b0>,
#   <matplotlib.patches.Wedge at 0x20a4cd156c0>,
#   <matplotlib.patches.Wedge at 0x20a4cd16200>,
#   <matplotlib.patches.Wedge at 0x20a4cd16830>,
#   <matplotlib.patches.Wedge at 0x20a4cd16ec0>,
#   <matplotlib.patches.Wedge at 0x20a4cd17550>,
#   <matplotlib.patches.Wedge at 0x20a4cd17be0>,
#   <matplotlib.patches.Wedge at 0x20a4cd582b0>,
#   <matplotlib.patches.Wedge at 0x20a4cd58940>,
#   <matplotlib.patches.Wedge at 0x20a4cd58fd0>,
#   <matplotlib.patches.Wedge at 0x20a4cd15780>,
#   <matplotlib.patches.Wedge at 0x20a4cd59cc0>,
#   <matplotlib.patches.Wedge at 0x20a4cd5a350>,
#   <matplotlib.patches.Wedge at 0x20a4cd5a9e0>,
#   <matplotlib.patches.Wedge at 0x20a4cd5b070>,
#   <matplotlib.patches.Wedge at 0x20a4cd5b700>,
#   <matplotlib.patches.Wedge at 0x20a4cd5bd90>,
#   <matplotlib.patches.Wedge at 0x20a4cd8c460>,
#   <matplotlib.patches.Wedge at 0x20a4cd8c700>,
#   <matplotlib.patches.Wedge at 0x20a4cd8cd90>,
#   <matplotlib.patches.Wedge at 0x20a4cd8d420>,
#   <matplotlib.patches.Wedge at 0x20a4cd8dab0>,
#   <matplotlib.patches.Wedge at 0x20a4cd8e140>,
#   <matplotlib.patches.Wedge at 0x20a4cd8e7d0>,
#   <matplotlib.patches.Wedge at 0x20a4cd8ee60>,
#   <matplotlib.patches.Wedge at 0x20a4cd8f4f0>,
#   <matplotlib.patches.Wedge at 0x20a4cd8fb80>,
#   <matplotlib.patches.Wedge at 0x20a4cdcc250>,
#   <matplotlib.patches.Wedge at 0x20a4cdcc8e0>,
#   <matplotlib.patches.Wedge at 0x20a4cdccf70>,
#   <matplotlib.patches.Wedge at 0x20a4cdcd600>,
#   <matplotlib.patches.Wedge at 0x20a4cdcdc90>,
#   <matplotlib.patches.Wedge at 0x20a4cdce320>,
#   <matplotlib.patches.Wedge at 0x20a4cdce9b0>,
#   <matplotlib.patches.Wedge at 0x20a4cdcf040>,
#   <matplotlib.patches.Wedge at 0x20a4cdcf6d0>,
#   <matplotlib.patches.Wedge at 0x20a4cdcfd60>,
#   <matplotlib.patches.Wedge at 0x20a4ce04430>,
#   <matplotlib.patches.Wedge at 0x20a4ce04ac0>,
#   <matplotlib.patches.Wedge at 0x20a4ce05150>,
#   <matplotlib.patches.Wedge at 0x20a4ce057e0>,
#   <matplotlib.patches.Wedge at 0x20a4ce05e70>,
#   <matplotlib.patches.Wedge at 0x20a4ce06500>,
#   <matplotlib.patches.Wedge at 0x20a4ce06b90>,
#   <matplotlib.patches.Wedge at 0x20a4ce07220>,
#   <matplotlib.patches.Wedge at 0x20a4ce078b0>,
#   <matplotlib.patches.Wedge at 0x20a4ce07f40>,
#   <matplotlib.patches.Wedge at 0x20a4ce38610>,
#   <matplotlib.patches.Wedge at 0x20a4ce38ca0>,
#   <matplotlib.patches.Wedge at 0x20a4ce39330>,
#   <matplotlib.patches.Wedge at 0x20a4ce399c0>,
#   <matplotlib.patches.Wedge at 0x20a4ce3a050>,
#   <matplotlib.patches.Wedge at 0x20a4ce3a6e0>,
#   <matplotlib.patches.Wedge at 0x20a4ce3ad70>,
#   <matplotlib.patches.Wedge at 0x20a4ce3b400>,
#   <matplotlib.patches.Wedge at 0x20a4ce3ba90>,
#   <matplotlib.patches.Wedge at 0x20a4ce78160>,
#   <matplotlib.patches.Wedge at 0x20a4ce787f0>,
#   <matplotlib.patches.Wedge at 0x20a4ce78e80>,
#   <matplotlib.patches.Wedge at 0x20a4ce79510>,
#   <matplotlib.patches.Wedge at 0x20a4ce79ba0>,
#   <matplotlib.patches.Wedge at 0x20a4ce7a230>,
#   <matplotlib.patches.Wedge at 0x20a4ce7a8c0>,
#   <matplotlib.patches.Wedge at 0x20a4ce7af50>,
#   <matplotlib.patches.Wedge at 0x20a4ce7b5e0>,
#   <matplotlib.patches.Wedge at 0x20a4ce7bc70>,
#   <matplotlib.patches.Wedge at 0x20a4ceb4340>,
#   <matplotlib.patches.Wedge at 0x20a4ceb49d0>,
#   <matplotlib.patches.Wedge at 0x20a4ceb5060>,
#   <matplotlib.patches.Wedge at 0x20a4ceb56f0>,
#   <matplotlib.patches.Wedge at 0x20a4ceb5d80>,
#   <matplotlib.patches.Wedge at 0x20a4ceb6410>,
#   <matplotlib.patches.Wedge at 0x20a4ceb6aa0>,
#   <matplotlib.patches.Wedge at 0x20a4ceb7130>,
#   <matplotlib.patches.Wedge at 0x20a4ceb77c0>,
#   <matplotlib.patches.Wedge at 0x20a4ceb7e50>,
#   <matplotlib.patches.Wedge at 0x20a4cef0520>,
#   <matplotlib.patches.Wedge at 0x20a4cef0bb0>,
#   <matplotlib.patches.Wedge at 0x20a4cef1240>,
#   <matplotlib.patches.Wedge at 0x20a4cef18d0>,
#   <matplotlib.patches.Wedge at 0x20a4cef1f60>,
#   <matplotlib.patches.Wedge at 0x20a4cef25f0>,
#   <matplotlib.patches.Wedge at 0x20a4cef2c80>,
#   <matplotlib.patches.Wedge at 0x20a4cef3310>,
#   <matplotlib.patches.Wedge at 0x20a4cef39a0>,
#   <matplotlib.patches.Wedge at 0x20a4cf24070>,
#   <matplotlib.patches.Wedge at 0x20a4cf24700>,
#   <matplotlib.patches.Wedge at 0x20a4cf24d90>,
#   <matplotlib.patches.Wedge at 0x20a4cf25420>,
#   <matplotlib.patches.Wedge at 0x20a4cf25ab0>,
#   <matplotlib.patches.Wedge at 0x20a4cf26140>,
#   <matplotlib.patches.Wedge at 0x20a4cf267d0>,
#   <matplotlib.patches.Wedge at 0x20a4cf26e60>,
#   <matplotlib.patches.Wedge at 0x20a4cf274f0>,
#   <matplotlib.patches.Wedge at 0x20a4cf27b80>,
#   <matplotlib.patches.Wedge at 0x20a4cf64250>,
#   <matplotlib.patches.Wedge at 0x20a4cf648e0>,
#   <matplotlib.patches.Wedge at 0x20a4cf64f70>,
#   <matplotlib.patches.Wedge at 0x20a4cf65600>,
#   <matplotlib.patches.Wedge at 0x20a4cf65c90>,
#   <matplotlib.patches.Wedge at 0x20a4cf66320>,
#   <matplotlib.patches.Wedge at 0x20a4cf669b0>,
#   <matplotlib.patches.Wedge at 0x20a4cf67040>,
#   <matplotlib.patches.Wedge at 0x20a4cf676d0>,
#   <matplotlib.patches.Wedge at 0x20a4cf67d60>,
#   <matplotlib.patches.Wedge at 0x20a4cfa0430>,
#   <matplotlib.patches.Wedge at 0x20a4cfa0ac0>,
#   <matplotlib.patches.Wedge at 0x20a4cfa1150>,
#   <matplotlib.patches.Wedge at 0x20a4cfa17e0>,
#   <matplotlib.patches.Wedge at 0x20a4cfa1e70>,
#   <matplotlib.patches.Wedge at 0x20a4cfa2500>,
#   <matplotlib.patches.Wedge at 0x20a4cfa2b90>,
#   <matplotlib.patches.Wedge at 0x20a4cfa3220>,
#   <matplotlib.patches.Wedge at 0x20a4cfa38b0>,
#   <matplotlib.patches.Wedge at 0x20a4cfa3f40>,
#   <matplotlib.patches.Wedge at 0x20a4cfe0610>,
#   <matplotlib.patches.Wedge at 0x20a4cfe0ca0>,
#   <matplotlib.patches.Wedge at 0x20a4cfe1330>,
#   <matplotlib.patches.Wedge at 0x20a4cfe19c0>,
#   <matplotlib.patches.Wedge at 0x20a4cfe2050>,
#   <matplotlib.patches.Wedge at 0x20a4cfe26e0>,
#   <matplotlib.patches.Wedge at 0x20a4cfe2d70>,
#   <matplotlib.patches.Wedge at 0x20a4cfe3400>,
#   <matplotlib.patches.Wedge at 0x20a4cfe3a90>,
#   <matplotlib.patches.Wedge at 0x20a4d018160>,
#   <matplotlib.patches.Wedge at 0x20a4d0187f0>,
#   <matplotlib.patches.Wedge at 0x20a4d018e80>,
#   <matplotlib.patches.Wedge at 0x20a4d019540>,
#   <matplotlib.patches.Wedge at 0x20a4d019bd0>,
#   <matplotlib.patches.Wedge at 0x20a4d01a260>,
#   <matplotlib.patches.Wedge at 0x20a4d01a8f0>,
#   <matplotlib.patches.Wedge at 0x20a4d01af80>,
#   <matplotlib.patches.Wedge at 0x20a4d01b610>,
#   <matplotlib.patches.Wedge at 0x20a4d01bca0>,
#   <matplotlib.patches.Wedge at 0x20a4d050370>,
#   <matplotlib.patches.Wedge at 0x20a4d050a00>,
#   <matplotlib.patches.Wedge at 0x20a4d051090>,
#   <matplotlib.patches.Wedge at 0x20a4d051720>,
#   <matplotlib.patches.Wedge at 0x20a4d051db0>,
#   <matplotlib.patches.Wedge at 0x20a4d052440>,
#   <matplotlib.patches.Wedge at 0x20a4d052ad0>,
#   <matplotlib.patches.Wedge at 0x20a4d053160>,
#   <matplotlib.patches.Wedge at 0x20a4d0537f0>,
#   <matplotlib.patches.Wedge at 0x20a4d053e80>,
#   <matplotlib.patches.Wedge at 0x20a4d090550>,
#   <matplotlib.patches.Wedge at 0x20a4d090be0>,
#   <matplotlib.patches.Wedge at 0x20a4d091270>,
#   <matplotlib.patches.Wedge at 0x20a4d091900>,
#   <matplotlib.patches.Wedge at 0x20a4d091f90>,
#   <matplotlib.patches.Wedge at 0x20a4d092620>,
#   <matplotlib.patches.Wedge at 0x20a4d092cb0>,
#   <matplotlib.patches.Wedge at 0x20a4d093340>,
#   <matplotlib.patches.Wedge at 0x20a4d0939d0>,
#   <matplotlib.patches.Wedge at 0x20a4d0d40a0>,
#   <matplotlib.patches.Wedge at 0x20a4d0d4730>,
#   <matplotlib.patches.Wedge at 0x20a4d0d4dc0>,
#   <matplotlib.patches.Wedge at 0x20a4d0d5450>,
#   <matplotlib.patches.Wedge at 0x20a4d0d5ae0>,
#   <matplotlib.patches.Wedge at 0x20a4d0d6170>,
#   <matplotlib.patches.Wedge at 0x20a4d0d6800>,
#   <matplotlib.patches.Wedge at 0x20a4d0d6e90>,
#   <matplotlib.patches.Wedge at 0x20a4d0d7520>,
#   <matplotlib.patches.Wedge at 0x20a4d0d7bb0>,
#   <matplotlib.patches.Wedge at 0x20a4d108280>,
#   <matplotlib.patches.Wedge at 0x20a4d108910>,
#   <matplotlib.patches.Wedge at 0x20a4d108fa0>,
#   <matplotlib.patches.Wedge at 0x20a4d109630>,
#   <matplotlib.patches.Wedge at 0x20a4d109cc0>,
#   <matplotlib.patches.Wedge at 0x20a4d10a350>,
#   <matplotlib.patches.Wedge at 0x20a4d10a9e0>,
#   <matplotlib.patches.Wedge at 0x20a4d10b070>,
#   <matplotlib.patches.Wedge at 0x20a4d10b700>,
#   <matplotlib.patches.Wedge at 0x20a4d10bd90>,
#   <matplotlib.patches.Wedge at 0x20a4d144460>,
#   <matplotlib.patches.Wedge at 0x20a4d144af0>,
#   <matplotlib.patches.Wedge at 0x20a4d145180>,
#   <matplotlib.patches.Wedge at 0x20a4d145810>,
#   <matplotlib.patches.Wedge at 0x20a4d145ea0>,
#   <matplotlib.patches.Wedge at 0x20a4d146530>,
#   <matplotlib.patches.Wedge at 0x20a4d146bc0>,
#   <matplotlib.patches.Wedge at 0x20a4d147250>,
#   <matplotlib.patches.Wedge at 0x20a4d1478e0>,
#   <matplotlib.patches.Wedge at 0x20a4d147f70>,
#   <matplotlib.patches.Wedge at 0x20a4d17c640>,
#   <matplotlib.patches.Wedge at 0x20a4d17ccd0>,
#   <matplotlib.patches.Wedge at 0x20a4d17d360>,
#   <matplotlib.patches.Wedge at 0x20a4d17d9f0>,
#   <matplotlib.patches.Wedge at 0x20a4d17e080>,
#   <matplotlib.patches.Wedge at 0x20a4d17e710>,
#   <matplotlib.patches.Wedge at 0x20a4d17eda0>,
#   <matplotlib.patches.Wedge at 0x20a4d17f430>,
#   <matplotlib.patches.Wedge at 0x20a4d17fac0>,
#   <matplotlib.patches.Wedge at 0x20a4d1bc190>,
#   <matplotlib.patches.Wedge at 0x20a4d1bc820>,
#   <matplotlib.patches.Wedge at 0x20a4d1bceb0>,
#   <matplotlib.patches.Wedge at 0x20a4d1bd540>,
#   <matplotlib.patches.Wedge at 0x20a4d1bdbd0>,
#   <matplotlib.patches.Wedge at 0x20a4d1be260>,
#   <matplotlib.patches.Wedge at 0x20a4d1be8f0>,
#   <matplotlib.patches.Wedge at 0x20a4d1bef80>,
#   <matplotlib.patches.Wedge at 0x20a4d1bf610>,
#   <matplotlib.patches.Wedge at 0x20a4d1bfca0>,
#   <matplotlib.patches.Wedge at 0x20a4d1fc370>,
#   <matplotlib.patches.Wedge at 0x20a4d1fca00>,
#   <matplotlib.patches.Wedge at 0x20a4d1fd090>,
#   <matplotlib.patches.Wedge at 0x20a4d1fd720>,
#   <matplotlib.patches.Wedge at 0x20a4d1fddb0>,
#   <matplotlib.patches.Wedge at 0x20a4d1fe440>,
#   <matplotlib.patches.Wedge at 0x20a4d1fead0>,
#   <matplotlib.patches.Wedge at 0x20a4d1ff160>,
#   <matplotlib.patches.Wedge at 0x20a4d1ff7f0>,
#   <matplotlib.patches.Wedge at 0x20a4d1ffe80>,
#   <matplotlib.patches.Wedge at 0x20a4d238550>,
#   <matplotlib.patches.Wedge at 0x20a4d238be0>,
#   <matplotlib.patches.Wedge at 0x20a4d239270>,
#   <matplotlib.patches.Wedge at 0x20a4d239900>,
#   <matplotlib.patches.Wedge at 0x20a4d239f90>,
#   <matplotlib.patches.Wedge at 0x20a4d23a620>,
#   <matplotlib.patches.Wedge at 0x20a4d23acb0>,
#   <matplotlib.patches.Wedge at 0x20a4d23b340>,
#   <matplotlib.patches.Wedge at 0x20a4d23b9d0>,
#   <matplotlib.patches.Wedge at 0x20a4d26c0a0>,
#   <matplotlib.patches.Wedge at 0x20a4d26c730>,
#   <matplotlib.patches.Wedge at 0x20a4d26cdc0>,
#   <matplotlib.patches.Wedge at 0x20a4d26d450>,
#   <matplotlib.patches.Wedge at 0x20a4d26dae0>,
#   <matplotlib.patches.Wedge at 0x20a4d26e170>,
#   <matplotlib.patches.Wedge at 0x20a4d26e800>,
#   <matplotlib.patches.Wedge at 0x20a4d26ee90>,
#   <matplotlib.patches.Wedge at 0x20a4d26f520>,
#   <matplotlib.patches.Wedge at 0x20a4d26fbb0>,
#   <matplotlib.patches.Wedge at 0x20a4d2a8280>,
#   <matplotlib.patches.Wedge at 0x20a4d2a8910>,
#   <matplotlib.patches.Wedge at 0x20a4d2a8fa0>,
#   <matplotlib.patches.Wedge at 0x20a4d2a9630>,
#   <matplotlib.patches.Wedge at 0x20a4d2a9cc0>,
#   <matplotlib.patches.Wedge at 0x20a4d2aa350>,
#   <matplotlib.patches.Wedge at 0x20a4d2aa9e0>,
#   <matplotlib.patches.Wedge at 0x20a4d2ab070>,
#   <matplotlib.patches.Wedge at 0x20a4d2ab700>,
#   <matplotlib.patches.Wedge at 0x20a4d2abd90>,
#   <matplotlib.patches.Wedge at 0x20a4d2e4460>,
#   <matplotlib.patches.Wedge at 0x20a4d2e4af0>,
#   <matplotlib.patches.Wedge at 0x20a4d2e5180>,
#   <matplotlib.patches.Wedge at 0x20a4d2e5810>,
#   <matplotlib.patches.Wedge at 0x20a4d2e5ea0>,
#   <matplotlib.patches.Wedge at 0x20a4d2e6530>,
#   <matplotlib.patches.Wedge at 0x20a4d2e6bc0>,
#   <matplotlib.patches.Wedge at 0x20a4d2e7250>,
#   <matplotlib.patches.Wedge at 0x20a4d2e78e0>,
#   <matplotlib.patches.Wedge at 0x20a4d2e7f70>,
#   <matplotlib.patches.Wedge at 0x20a4d324640>,
#   <matplotlib.patches.Wedge at 0x20a4d324cd0>,
#   <matplotlib.patches.Wedge at 0x20a4d325360>,
#   <matplotlib.patches.Wedge at 0x20a4d3259f0>,
#   <matplotlib.patches.Wedge at 0x20a4d326080>,
#   <matplotlib.patches.Wedge at 0x20a4d326770>,
#   <matplotlib.patches.Wedge at 0x20a4d326e00>,
#   <matplotlib.patches.Wedge at 0x20a4d327490>,
#   <matplotlib.patches.Wedge at 0x20a4d327b20>,
#   <matplotlib.patches.Wedge at 0x20a4d35c1f0>,
#   <matplotlib.patches.Wedge at 0x20a4d35c880>,
#   <matplotlib.patches.Wedge at 0x20a4d35cf10>,
#   <matplotlib.patches.Wedge at 0x20a4d35d5a0>,
#   <matplotlib.patches.Wedge at 0x20a4d35dc30>,
#   <matplotlib.patches.Wedge at 0x20a4d35e2c0>,
#   <matplotlib.patches.Wedge at 0x20a4d35e950>,
#   <matplotlib.patches.Wedge at 0x20a4d35efe0>,
#   <matplotlib.patches.Wedge at 0x20a4d35f670>,
#   <matplotlib.patches.Wedge at 0x20a4d35fd00>,
#   <matplotlib.patches.Wedge at 0x20a4d3943d0>,
#   <matplotlib.patches.Wedge at 0x20a4d394a60>,
#   <matplotlib.patches.Wedge at 0x20a4d3950f0>,
#   <matplotlib.patches.Wedge at 0x20a4d395780>,
#   <matplotlib.patches.Wedge at 0x20a4d395e10>,
#   <matplotlib.patches.Wedge at 0x20a4d3964a0>,
#   <matplotlib.patches.Wedge at 0x20a4d396b30>,
#   <matplotlib.patches.Wedge at 0x20a4d3971c0>,
#   <matplotlib.patches.Wedge at 0x20a4d397850>,
#   <matplotlib.patches.Wedge at 0x20a4d397ee0>,
#   <matplotlib.patches.Wedge at 0x20a4d3d05b0>,
#   <matplotlib.patches.Wedge at 0x20a4d3d0c40>,
#   <matplotlib.patches.Wedge at 0x20a4d3d12d0>,
#   <matplotlib.patches.Wedge at 0x20a4d3d1960>,
#   <matplotlib.patches.Wedge at 0x20a4d3d1ff0>,
#   <matplotlib.patches.Wedge at 0x20a4d3d2680>,
#   <matplotlib.patches.Wedge at 0x20a4d3d2d10>,
#   <matplotlib.patches.Wedge at 0x20a4d3d33a0>,
#   <matplotlib.patches.Wedge at 0x20a4d3d3a30>,
#   <matplotlib.patches.Wedge at 0x20a4d410100>,
#   <matplotlib.patches.Wedge at 0x20a4d410790>,
#   <matplotlib.patches.Wedge at 0x20a4d410e20>,
#   <matplotlib.patches.Wedge at 0x20a4d4114b0>,
#   <matplotlib.patches.Wedge at 0x20a4d411b40>,
#   <matplotlib.patches.Wedge at 0x20a4d4121d0>,
#   <matplotlib.patches.Wedge at 0x20a4d412860>,
#   <matplotlib.patches.Wedge at 0x20a4d412ef0>,
#   <matplotlib.patches.Wedge at 0x20a4d413580>,
#   <matplotlib.patches.Wedge at 0x20a4d413c10>,
#   <matplotlib.patches.Wedge at 0x20a4d4482e0>,
#   <matplotlib.patches.Wedge at 0x20a4d448970>,
#   <matplotlib.patches.Wedge at 0x20a4d449000>,
#   <matplotlib.patches.Wedge at 0x20a4d449690>,
#   <matplotlib.patches.Wedge at 0x20a4d449d20>,
#   <matplotlib.patches.Wedge at 0x20a4d44a3b0>,
#   <matplotlib.patches.Wedge at 0x20a4d44aa40>,
#   <matplotlib.patches.Wedge at 0x20a4d44b0d0>,
#   <matplotlib.patches.Wedge at 0x20a4d44b760>,
#   <matplotlib.patches.Wedge at 0x20a4d44bdf0>,
#   <matplotlib.patches.Wedge at 0x20a4d4884c0>,
#   <matplotlib.patches.Wedge at 0x20a4d488b50>,
#   <matplotlib.patches.Wedge at 0x20a4d4891e0>,
#   <matplotlib.patches.Wedge at 0x20a4d489870>,
#   <matplotlib.patches.Wedge at 0x20a4d489f00>,
#   <matplotlib.patches.Wedge at 0x20a4d48a590>,
#   <matplotlib.patches.Wedge at 0x20a4d48ac20>,
#   <matplotlib.patches.Wedge at 0x20a4d48b2b0>,
#   <matplotlib.patches.Wedge at 0x20a4d48b940>,
#   <matplotlib.patches.Wedge at 0x20a4d48bfd0>,
#   <matplotlib.patches.Wedge at 0x20a4d4c06a0>,
#   <matplotlib.patches.Wedge at 0x20a4d4c0d30>,
#   <matplotlib.patches.Wedge at 0x20a4d4c13f0>,
#   <matplotlib.patches.Wedge at 0x20a4d4c1a80>,
#   <matplotlib.patches.Wedge at 0x20a4d4c2110>,
#   <matplotlib.patches.Wedge at 0x20a4d4c27a0>,
#   <matplotlib.patches.Wedge at 0x20a4d4c2e30>,
#   <matplotlib.patches.Wedge at 0x20a4d4c34c0>,
#   <matplotlib.patches.Wedge at 0x20a4d4c3b50>,
#   <matplotlib.patches.Wedge at 0x20a4d4f8220>,
#   <matplotlib.patches.Wedge at 0x20a4d4f88b0>,
#   <matplotlib.patches.Wedge at 0x20a4d4f8f40>,
#   <matplotlib.patches.Wedge at 0x20a4d4f95d0>,
#   <matplotlib.patches.Wedge at 0x20a4d4f9c60>,
#   <matplotlib.patches.Wedge at 0x20a4d4fa2f0>,
#   <matplotlib.patches.Wedge at 0x20a4d4fa980>,
#   <matplotlib.patches.Wedge at 0x20a4d4fb010>,
#   <matplotlib.patches.Wedge at 0x20a4d4fb6a0>,
#   <matplotlib.patches.Wedge at 0x20a4d4fbd30>,
#   <matplotlib.patches.Wedge at 0x20a4d534400>,
#   <matplotlib.patches.Wedge at 0x20a4d534a90>,
#   <matplotlib.patches.Wedge at 0x20a4d535120>,
#   <matplotlib.patches.Wedge at 0x20a4d5357b0>,
#   <matplotlib.patches.Wedge at 0x20a4d535e40>,
#   <matplotlib.patches.Wedge at 0x20a4d5364d0>,
#   <matplotlib.patches.Wedge at 0x20a4d536b60>,
#   <matplotlib.patches.Wedge at 0x20a4d5371f0>,
#   <matplotlib.patches.Wedge at 0x20a4d537880>,
#   <matplotlib.patches.Wedge at 0x20a4d537f10>,
#   <matplotlib.patches.Wedge at 0x20a4d5705e0>,
#   <matplotlib.patches.Wedge at 0x20a4d570c70>,
#   <matplotlib.patches.Wedge at 0x20a4d571300>,
#   <matplotlib.patches.Wedge at 0x20a4d571990>,
#   <matplotlib.patches.Wedge at 0x20a4d572020>,
#   <matplotlib.patches.Wedge at 0x20a4d5726b0>,
#   <matplotlib.patches.Wedge at 0x20a4d572d40>,
#   <matplotlib.patches.Wedge at 0x20a4d5733d0>,
#   <matplotlib.patches.Wedge at 0x20a4d573a60>,
#   <matplotlib.patches.Wedge at 0x20a4d5b0130>,
#   <matplotlib.patches.Wedge at 0x20a4d5b07c0>,
#   <matplotlib.patches.Wedge at 0x20a4d5b0e50>,
#   <matplotlib.patches.Wedge at 0x20a4d5b14e0>,
#   <matplotlib.patches.Wedge at 0x20a4d5b1b70>,
#   <matplotlib.patches.Wedge at 0x20a4d5b2200>,
#   <matplotlib.patches.Wedge at 0x20a4d5b2890>,
#   <matplotlib.patches.Wedge at 0x20a4d5b2f20>,
#   <matplotlib.patches.Wedge at 0x20a4d5b35b0>,
#   <matplotlib.patches.Wedge at 0x20a4d5b3c40>,
#   <matplotlib.patches.Wedge at 0x20a4d5e4310>,
#   <matplotlib.patches.Wedge at 0x20a4d5e49a0>,
#   <matplotlib.patches.Wedge at 0x20a4d5e5030>,
#   <matplotlib.patches.Wedge at 0x20a4d5e56c0>,
#   <matplotlib.patches.Wedge at 0x20a4d5e5d50>,
#   <matplotlib.patches.Wedge at 0x20a4d5e63e0>,
#   <matplotlib.patches.Wedge at 0x20a4d5e6a70>,
#   <matplotlib.patches.Wedge at 0x20a4d5e7100>,
#   <matplotlib.patches.Wedge at 0x20a4d5e7790>,
#   <matplotlib.patches.Wedge at 0x20a4d5e7e20>,
#   <matplotlib.patches.Wedge at 0x20a4d6204f0>,
#   <matplotlib.patches.Wedge at 0x20a4d620b80>,
#   <matplotlib.patches.Wedge at 0x20a4d621210>,
#   <matplotlib.patches.Wedge at 0x20a4d6218a0>,
#   <matplotlib.patches.Wedge at 0x20a4d621f30>,
#   <matplotlib.patches.Wedge at 0x20a4d6225c0>,
#   <matplotlib.patches.Wedge at 0x20a4d622c50>,
#   <matplotlib.patches.Wedge at 0x20a4d6232e0>,
#   <matplotlib.patches.Wedge at 0x20a4d623970>,
#   <matplotlib.patches.Wedge at 0x20a4d65c040>,
#   <matplotlib.patches.Wedge at 0x20a4d65c6d0>,
#   <matplotlib.patches.Wedge at 0x20a4d65cd60>,
#   <matplotlib.patches.Wedge at 0x20a4d65d3f0>,
#   <matplotlib.patches.Wedge at 0x20a4d65da80>,
#   <matplotlib.patches.Wedge at 0x20a4d65e110>,
#   <matplotlib.patches.Wedge at 0x20a4d65e7a0>,
#   <matplotlib.patches.Wedge at 0x20a4d65ee30>,
#   <matplotlib.patches.Wedge at 0x20a4d65f4c0>,
#   <matplotlib.patches.Wedge at 0x20a4d65fb50>,
#   <matplotlib.patches.Wedge at 0x20a4d698220>,
#   <matplotlib.patches.Wedge at 0x20a4d6988b0>,
#   <matplotlib.patches.Wedge at 0x20a4d698f40>,
#   <matplotlib.patches.Wedge at 0x20a4d6995d0>],
#  [Text(1.0999452709866646, 0.01097273138617181, ''),
#   Text(1.0995629174276842, 0.03100629964894103, ''),
#   Text(1.0989237948641577, 0.048646614284644625, ''),
#   Text(1.0979728392703734, 0.06675061216614359, ''),
#   Text(1.09678772806181, 0.08400404498006817, ''),
#   Text(1.0952211022392484, 0.10242429989922253, ''),
#   Text(1.0932134944873415, 0.1220010470068819, ''),
#   Text(0.5389090066104679, -0.2637746814880433, '0.25'),
#   Text(0.5434313505789403, -0.25432728364835094, '0.31'),
#   Text(0.5483968861797226, -0.24343552581409372, '0.33'),
#   Text(0.5528917867080201, -0.2330465022067766, '0.27'),
#   Text(0.5558281662385828, -0.22595364483861374, '0.13'),
#   Text(0.5576952493218419, -0.22130523916945252, '0.13'),
#   Text(0.5594059262837812, -0.21694471562724163, '0.12'),
#   Text(0.5612896802639814, -0.21202333557690659, '0.16'),
#   Text(0.5636225219647476, -0.20574171364625482, '0.19'),
#   Text(0.5664021319711405, -0.1979611701787668, '0.25'),
#   Text(0.5695262917614045, -0.18878507089413502, '0.27'),
#   Text(0.5725407285413466, -0.17943554319405056, '0.25'),
#   Text(0.5754753851808049, -0.16978834191723619, '0.28'),
#   Text(0.5780561451487589, -0.16078275111390805, '0.21'),
#   Text(0.5807256543714417, -0.15085660195981093, '0.33'),
#   Text(0.5837401488948427, -0.1387351381886606, '0.33'),
#   Text(0.5858069486558211, -0.12973133355730274, '0.16'),
#   Text(0.5871657562355098, -0.12343571081490909, '0.18'),
#   Text(0.5884949752963988, -0.11693444338983698, '0.17'),
#   Text(0.5900257460189477, -0.10894778122928492, '0.26'),
#   Text(0.5916115225034667, -0.09997903000694751, '0.22'),
#   Text(0.5930115616330349, -0.09130874968779926, '0.25'),
#   Text(0.5944623082391297, -0.08132997038611221, '0.29'),
#   Text(0.5957914288721391, -0.07094063209821885, '0.27'),
#   Text(0.5969717183131321, -0.06020604234017041, '0.31'),
#   Text(0.5979853366172396, -0.049127763950404336, '0.28'),
#   Text(0.5987726810525296, -0.0383572212909861, '0.29'),
#   Text(0.5993926719379898, -0.026989346547059066, '0.31'),
#   Text(0.5997670641635295, -0.016717318704283543, '0.23'),
#   Text(0.5999681703823135, -0.006180172173907663, '0.33')])

# %%
plt.plot(data['Chance_of_Admit'],data['TOEFL_Score'],marker='o')
plt.plot(data['Chance_of_Admit'],data['GRE_Score'],marker='x')
plt.xlabel('Chance_of_Admit')
plt.ylabel('TOEFL and GRE Scores')
# Out:
# Text(0, 0.5, 'TOEFL and GRE Scores')

# %%
#Pair Plot
sns.pairplot(data)

# %%
#Heat Map
hm=data.corr()
sns.heatmap(hm)
# Out:
# <Axes: >

# %%
#extracting numerical columns values
x_independent = data.iloc[:,:-1]
y_dependent=data.iloc[:,8:9]

# %%
#Dropping unnecessary columns
x_independent=x_independent.drop(['Serial_No'],axis=1)

# %%
x_independent
# Out:
#      GRE_Score  TOEFL_Score  University_Rating  SOP  LOR  CGPA  Research
# 0          337          118                  4  4.5  4.5  9.65         1
# 1          324          107                  4  4.0  4.5  8.87         1
# 2          316          104                  3  3.0  3.5  8.00         1
# 3          322          110                  3  3.5  2.5  8.67         1
# 4          314          103                  2  2.0  3.0  8.21         0
# ..         ...          ...                ...  ...  ...   ...       ...
# 395        324          110                  3  3.5  3.5  9.04         1
# 396        325          107                  3  3.0  3.5  9.11         1
# 397        330          116                  4  5.0  4.5  9.45         1
# 398        312          103                  3  3.5  4.0  8.78         0
# 399        333          117                  4  5.0  4.0  9.66         1
#
# [400 rows x 7 columns]

# %%
#Checking Outliers
sns.boxplot(x_independent)
# Out:
# <Axes: >

# %%
sns.boxplot(x_independent.LOR)
# Out:
# <Axes: >

# %%
sns.boxplot(x_independent.CGPA)
# Out:
# <Axes: >

# %%
#Calculating quartiles for x_independent
quantile = x_independent.quantile(q=[0.25,0.75])
quantile
# Out:
#       GRE_Score  TOEFL_Score  University_Rating  SOP  LOR    CGPA  Research
# 0.25      308.0        103.0                2.0  2.5  3.0  8.1700       0.0
# 0.75      325.0        112.0                4.0  4.0  4.0  9.0625       1.0

# %%
#IQR
IQR = quantile.iloc[1] - quantile.iloc[0]
IQR
# Out:
# GRE_Score            17.0000
# TOEFL_Score           9.0000
# University_Rating     2.0000
# SOP                   1.5000
# LOR                   1.0000
# CGPA                  0.8925
# Research              1.0000
# dtype: float64

# %%
#calculating upper extreme
upper_extreme = quantile.iloc[1] + (1.5*IQR)
upper_extreme
# Out:
# GRE_Score            350.50000
# TOEFL_Score          125.50000
# University_Rating      7.00000
# SOP                    6.25000
# LOR                    5.50000
# CGPA                  10.40125
# Research               2.50000
# dtype: float64

# %%
#calculating lower extreme
lower_extreme = quantile.iloc[0] - (1.5*IQR)
lower_extreme
# Out:
# GRE_Score            282.50000
# TOEFL_Score           89.50000
# University_Rating     -1.00000
# SOP                    0.25000
# LOR                    1.50000
# CGPA                   6.83125
# Research              -1.50000
# dtype: float64

# %%
#removing outliers from the extracted numeric columns

removed_outliers = x_independent[(x_independent >=lower_extreme)&(x_independent <=upper_extreme)]
removed_outliers
# Out:
#      GRE_Score  TOEFL_Score  University_Rating  SOP  LOR  CGPA  Research
# 0          337          118                  4  4.5  4.5  9.65         1
# 1          324          107                  4  4.0  4.5  8.87         1
# 2          316          104                  3  3.0  3.5  8.00         1
# 3          322          110                  3  3.5  2.5  8.67         1
# 4          314          103                  2  2.0  3.0  8.21         0
# ..         ...          ...                ...  ...  ...   ...       ...
# 395        324          110                  3  3.5  3.5  9.04         1
# 396        325          107                  3  3.0  3.5  9.11         1
# 397        330          116                  4  5.0  4.5  9.45         1
# 398        312          103                  3  3.5  4.0  8.78         0
# 399        333          117                  4  5.0  4.0  9.66         1
#
# [400 rows x 7 columns]

# %%
removed_outliers.to_csv('file1.csv')

# %%
#Finding null values after removing outliers
removed_outliers.isnull().any()
# Out:
# GRE_Score            False
# TOEFL_Score          False
# University_Rating    False
# SOP                  False
# LOR                   True
# CGPA                  True
# Research             False
# dtype: bool

# %%
#Replacing null values
removed_outliers['LOR'].fillna(removed_outliers['LOR'].mean(),inplace=True)
removed_outliers['CGPA'].fillna(removed_outliers['CGPA'].mean(),inplace=True)

# %%
#Checking whether null values are removed
removed_outliers.isnull().sum()
# Out:
# GRE_Score            0
# TOEFL_Score          0
# University_Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# dtype: int64

# %%
removed_outliers
# Out:
#      GRE_Score  TOEFL_Score  University_Rating  SOP  LOR  CGPA  Research
# 0          337          118                  4  4.5  4.5  9.65         1
# 1          324          107                  4  4.0  4.5  8.87         1
# 2          316          104                  3  3.0  3.5  8.00         1
# 3          322          110                  3  3.5  2.5  8.67         1
# 4          314          103                  2  2.0  3.0  8.21         0
# ..         ...          ...                ...  ...  ...   ...       ...
# 395        324          110                  3  3.5  3.5  9.04         1
# 396        325          107                  3  3.0  3.5  9.11         1
# 397        330          116                  4  5.0  4.5  9.45         1
# 398        312          103                  3  3.5  4.0  8.78         0
# 399        333          117                  4  5.0  4.0  9.66         1
#
# [400 rows x 7 columns]

# %%
#Removed outliers Boxplot
sns.boxplot(removed_outliers)
# Out:
# <Axes: >

# %% [markdown]
# # Scaling

# %%
name=removed_outliers.columns
name
# Out:
# Index(['GRE_Score', 'TOEFL_Score', 'University_Rating', 'SOP', 'LOR', 'CGPA',
#        'Research'],
#       dtype='object')

# %%
#Normalisation
from sklearn.preprocessing import MinMaxScaler

# %%
scale=MinMaxScaler()

# %%
X_scaled=scale.fit_transform(removed_outliers)

# %%
X=pd.DataFrame(X_scaled,columns=name)

# %%
X
# Out:
#      GRE_Score  TOEFL_Score  University_Rating    SOP       LOR      CGPA  \
# 0         0.94     0.928571               0.75  0.875  0.857143  0.900735
# 1         0.68     0.535714               0.75  0.750  0.857143  0.613971
# 2         0.52     0.428571               0.50  0.500  0.571429  0.294118
# 3         0.64     0.642857               0.50  0.625  0.285714  0.540441
# 4         0.48     0.392857               0.25  0.250  0.428571  0.371324
# ..         ...          ...                ...    ...       ...       ...
# 395       0.68     0.642857               0.50  0.625  0.571429  0.676471
# 396       0.70     0.535714               0.50  0.500  0.571429  0.702206
# 397       0.80     0.857143               0.75  1.000  0.857143  0.827206
# 398       0.44     0.392857               0.50  0.625  0.714286  0.580882
# 399       0.86     0.892857               0.75  1.000  0.714286  0.904412
#
#      Research
# 0         1.0
# 1         1.0
# 2         1.0
# 3         1.0
# 4         0.0
# ..        ...
# 395       1.0
# 396       1.0
# 397       1.0
# 398       0.0
# 399       1.0
#
# [400 rows x 7 columns]

# %% [markdown]
# # Split the data into dependent and independent variables

# %%
#Split the data into dependent and independent variables
x=X #independent values
y=y_dependent

# %%
x
# Out:
#      GRE_Score  TOEFL_Score  University_Rating    SOP       LOR      CGPA  \
# 0         0.94     0.928571               0.75  0.875  0.857143  0.900735
# 1         0.68     0.535714               0.75  0.750  0.857143  0.613971
# 2         0.52     0.428571               0.50  0.500  0.571429  0.294118
# 3         0.64     0.642857               0.50  0.625  0.285714  0.540441
# 4         0.48     0.392857               0.25  0.250  0.428571  0.371324
# ..         ...          ...                ...    ...       ...       ...
# 395       0.68     0.642857               0.50  0.625  0.571429  0.676471
# 396       0.70     0.535714               0.50  0.500  0.571429  0.702206
# 397       0.80     0.857143               0.75  1.000  0.857143  0.827206
# 398       0.44     0.392857               0.50  0.625  0.714286  0.580882
# 399       0.86     0.892857               0.75  1.000  0.714286  0.904412
#
#      Research
# 0         1.0
# 1         1.0
# 2         1.0
# 3         1.0
# 4         0.0
# ..        ...
# 395       1.0
# 396       1.0
# 397       1.0
# 398       0.0
# 399       1.0
#
# [400 rows x 7 columns]

# %%
y
# Out:
#      Chance_of_Admit
# 0               0.92
# 1               0.76
# 2               0.72
# 3               0.80
# 4               0.65
# ..               ...
# 395             0.82
# 396             0.84
# 397             0.91
# 398             0.67
# 399             0.95
#
# [400 rows x 1 columns]

# %% [markdown]
# # Train-Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=9)

# %% [markdown]
# # Build the Model

# %%
#Multi Linear Regression
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %%
#importing Ridge Regression
from sklearn.linear_model import Ridge
r=Ridge()

# %% [markdown]
# # Train the model

# %%
#Training Linear Regression Model
model.fit(x_train.values,y_train.values)
# Out:
# LinearRegression()

# %%
#Training Ridge Regression Model
r.fit(x_train,y_train)
# Out:
# Ridge()

# %% [markdown]
# # Testing the Model

# %%
#Testing Linear Regression Model
pred=model.predict(x_test)
# Out:
# C:\Users\nagap\Documents\Anaconda\lib\site-packages\sklearn\base.py:413: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(

# %%
#Testing Ridge Regression Model
pred1=r.predict(x_test)

# %% [markdown]
# # Measure the performance using Metrics

# %%
from sklearn import metrics

# %%
# R Squared for MultiLinear Regression
print(metrics.r2_score(y_test,pred))
# Out:
# 0.8404358111467283

# %%
# R Squared for Ridge Regression
print(metrics.r2_score(y_test,pred1))
# Out:
# 0.8327761441584975

# %%
#MSE (Mean Square Error)  for MultiLinear Regression
print(metrics.mean_squared_error(y_test,pred))
# Out:
# 0.003260534635027756

# %%
#MSE (Mean Square Error) for Ridge Regression
print(metrics.mean_squared_error(y_test,pred1))
# Out:
# 0.0034170522702652597

# %%
#RMSE(Root Mean Square Error) for MultiLinear Regression
print(np.sqrt(metrics.mean_squared_error(y_test,pred)))
# Out:
# 0.05710109136459439

# %%
#RMSE(Root Mean Square Error) for Ridge Regression
print(np.sqrt(metrics.mean_squared_error(y_test,pred1)))
# Out:
# 0.05845555807846898

# %%
def calc(a,b,c,d,e,f,g):
    myarr = np.array([a,b,c,d,e,f,g])
    mydf = pd.Series(myarr, index=["GRE_Score", "TOEFL_Score", "University_Rating", "SOP", "LOR", "CGPA", "Research"])
    removed_outliers.columns = removed_outliers.columns.astype(str)
    frames = [removed_outliers,mydf.to_frame().T]
    result = pd.concat(frames,ignore_index=True)
    mydfs = scale.fit_transform(result)
    ans = pd.DataFrame(mydfs)
    return ans[0][400],ans[1][400],ans[2][400],ans[3][400],ans[4][400],ans[5][400],ans[6][400]
#     print(myans)
#     return myans

# %%
model.predict([calc(337,118,4,4.5,4.5,9.65,1)])
# Out:
# array([[0.94749055]])

# %%
# def calc(a,b,c,d,e,f,g):
#     myarr = np.array([a,b,c,d,e,f,g])
#     mydf = pd.Series(myarr, index=["GRE_Score", "TOEFL_Score", "University_Rating", "SOP", "LOR", "CGPA", "Research"])
#     removed_outliers.columns = removed_outliers.columns.astype(str)
#     frames = [removed_outliers,mydf.to_frame().T]
#     result = pd.concat(frames,ignore_index=True)
#     mydfs = scale.fit_transform(result)
#     ans = pd.DataFrame(mydfs)
#     myans = (model.predict([[ans[0][400],ans[1][400],ans[2][400],ans[3][400],ans[4][400],ans[5][400],ans[6][400]]])*100)
#     print(myans)
#     return myans

# %%
calc(337,118,4,4.5,4.5,9.65,1)
# Out:
# (0.9400000000000004,
#  0.9285714285714288,
#  0.75,
#  0.875,
#  0.857142857142857,
#  0.9007352941176472,
#  1.0)

# %%
model.predict([[337,118,4,4.5,4.5,9.65,1]])
# Out:
# array([[54.26945998]])

# %%
model.predict([[337,118,4,4.5,4.5,9.65,1]])
# Out:
# array([[54.26945998]])

# %%
model.predict([[0.94,0.928571,0.75,0.875,0.8571,0.900735,1]])
# Out:
# array([[0.94748759]])

# %%
import pickle
pickle.dump(model,open("model.pkl","wb"))
